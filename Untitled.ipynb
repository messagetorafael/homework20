# %%
import pandas as pd

# %%
data = pd.read_csv("citibike-tripdata.csv")
print(len(data))
display(data.head(2))

data201802 = pd.read_csv("201802-citibike-tripdata.csv")
print(len(data201802))
display(data201802.head(2))

data201801 = pd.read_csv("201801-citibike-tripdata.csv")
print(len(data201801))
display(data201801.head(2))

data201712 = pd.read_csv("201712-citibike-tripdata.csv")
print(len(data201712))
display(data201712.head(2))

data201711 = pd.read_csv("201711-citibike-tripdata.csv")
data201711.insert(loc=0,column="date",value="11/1/2017")
print(len(data201711))
display(data201711.head(2))


data201710 = pd.read_csv("201710-citibike-tripdata.csv")
data201710.insert(loc=0,column="date",value="10/1/2017")
print(len(data201710))
display(data201710.head(2))

data201709 = pd.read_csv("201709-citibike-tripdata.csv")
data201709.insert(loc=0,column="date",value="09/1/2017")
print(len(data201709))
display(data201709.head(2))


data201708 = pd.read_csv("JC-201708 citibike-tripdata.csv")
data201708.insert(loc=0,column="date",value="08/1/2017")
print(len(data201708))
display(data201708.head(2))


data201707 = pd.read_csv("201707-citibike-tripdata.csv")
data201707.insert(loc=0,column="date",value="07/1/2017")
print(len(data201707))
display(data201707.head(2))


data201706 = pd.read_csv("JC-201706-citibike-tripdata.csv")
data201706.insert(loc=0,column="date",value="06/1/2017")
print(len(data201706))
display(data201706.head(2))
# Out:
# 496580
#        date  tripduration starttime stoptime  start station id  \
# 0  6/1/2019         316.0   05:55.7  11:12.0            3187.0
# 1  6/1/2019         280.0   08:09.1  12:50.1            3185.0
#
#   start station name  start station latitude  start station longitude  \
# 0          Warren St               40.721124               -74.038051
# 1          City Hall               40.717733               -74.043845
#
#    end station id end station name  end station latitude  \
# 0          3199.0     Newport Pkwy             40.728745
# 1          3267.0     Morris Canal             40.712419
#
#    end station longitude   bikeid    usertype  birth year  gender
# 0             -74.032108  29677.0  Subscriber      1993.0     1.0
# 1             -74.038526  29571.0  Subscriber      1984.0     1.0
# 843114
#        date  tripduration starttime stoptime  start station id  \
# 0  2/1/2018           771   14:16.4  27:08.2                72
# ...

# %%
maindf = data.append(data201802,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201801,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201712,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201711,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201710,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201709,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201708,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201707,ignore_index = True)
print(len(maindf))
maindf = maindf.append(data201706,ignore_index = True)
print(len(maindf))
# Out:
# 1339694
# 2058688
# 2948655
# 4279304
# 6176896
# 8054994
# 8090466
# 9826065
# 9858125

# %%
maindf.to_csv("citybike-Jun2017-Jun2019.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-735be628f404> in <module>
# ----> 1 maindf.to_csv("citybike-Jun2017-Jun2019.csv",index=False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# ...
